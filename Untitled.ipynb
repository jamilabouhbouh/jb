# %%
from deep import Net_sig

# %%
import hiddenlayer as hl

# %%
cd ..
# Out:
# /scratch/ojgurney-champion/GIT

# %%
cd hidden_layer
# Out:
# /scratch/ojgurney-champion/GIT/hidden_layer

# %%
cd hiddenlayer
# Out:
# /scratch/ojgurney-champion/GIT/hidden_layer/hiddenlayer

# %%
cd ..
# Out:
# /scratch/ojgurney-champion/GIT/hidden_layer

# %%
cd ..
# Out:
# /scratch/ojgurney-champion/GIT

# %%
cd IVIM-NET
# Out:
# /scratch/ojgurney-champion/GIT/IVIM-NET

# %%
import numpy as np
import torch as torch
bval=torch.Tensor(np.array([0, 10, 20, 30, 40, 50, 100, 200, 300, 500, 700]))
net=Net_sig(bval)

# %%
import torch as torch
device=torch.device('cpu')
aa=hl.build_graph(net.to(device), torch.zeros([11, 11]).to(device))

# %%
aa

# %%
from deep import Net_split
net=Net_split(bval)
bb=hl.build_graph(net.to(device), torch.zeros([11, 11]).to(device))
bb
